# %% [markdown]
# # Load pickle file with pred and targets

# %%
import pickle
import numpy as np
import os
import sklearn
from sklearn.metrics import f1_score
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Define path to your pickle file where targets and predictions are stored
seed = "80022"
pickle_file_test = "/home/projects/vokquant/accent-recog-slt2022/CommonAccent/results/W2V2/OFAI/mms-lid-256-augmented/" + seed + "/save/predictions/test_predictions.pkl"
# set:
pickle_file = pickle_file_test

combined_batch_ids = []
combined_predictions = []
combined_targets = []
combined_lens = []

# Open file and read all objects (batches). Otherwise only last batch is loaded
with open(pickle_file, "rb") as f:
    while True:
        try:
            batch = pickle.load(f)
            # Append data for each batch
            combined_batch_ids.extend(batch["batch_ids"])
            combined_predictions.append(batch["predictions"])
            combined_targets.append(batch["targets"])
            combined_lens.append(batch["lens"])
        except EOFError:
            break

# Concatenate predictions, targets, and lens across all batches
combined_predictions = np.concatenate(combined_predictions, axis=0)
combined_targets = np.concatenate(combined_targets, axis=0)
combined_lens = np.concatenate(combined_lens, axis=0)

print("len predictions: ", len(combined_predictions))
print("len targets: ", len(combined_targets))
# Out:
# len predictions:  4582
# len targets:  4582

# %% [markdown]
# # Load accent_encoder file and create dict

# %%
accent_encoder = '/home/projects/vokquant/accent-recog-slt2022/CommonAccent/results/W2V2/OFAI/mms-lid-256-augmented/' + seed + '/save/accent_encoder.txt'
with open(accent_encoder, 'r') as f:
    accent_encoder = f.read().splitlines()

encoder_dict = {}
for line in accent_encoder[:-2]:
    region, encoding = line.split(' => ')
    # print(region, encoding)
    encoder_dict[encoding] = int(region.strip().strip("'"))
print(encoder_dict)

# ALTERNATIVE:  just type the class mapping:
# class_mapping = {
# '62390': 0, '70221': 1, '30860': 2, '31035': 3, '50413': 4, '41706': 5, '70709': 6, '80105': 7, '40719': 8, '70334': 9, '70406': 10, '31405': 11, '32210': 12, '70627': 13, '50304': 14, '70706': 15, '31207': 16, '40702': 17, '40423': 18, '40410': 19, '32309': 20, '41411': 21, '10702': 22, '70208': 23, '70734': 24, '50626': 25, '80225': 26, '30501': 27, '70622': 28, '40621': 29, '50621': 30, '62216': 31, '41342': 32, '61032': 33, '30910': 34, '10903': 35, '50617': 36, '31110': 37, '70615': 38, '20622': 39, '20914': 40, '80411': 41, '50612': 42, '50502': 43, '61627': 44, '32324': 45, '70516': 46, '10925': 47, '40806': 48, '80239': 49, '20321': 50, '80227': 51, '70804': 52, '80128': 53, '41804': 54, '31652': 55, '61257': 56, '30719': 57, '60350': 58, '50509': 59, '70402': 60, '20619': 61, '10401': 62, '61628': 63, '70824': 64, '70606': 65, '50206': 66, '61254': 67, '62105': 68, '31916': 69, '50210': 70, '40402': 71, '61115': 72, '70908': 73, '70419': 74, '70366': 75, '61743': 76, '32518': 77, '40914': 78, '31617': 79, '31401': 80, '50212': 81, '80212': 82, '41501': 83, '70326': 84, '40605': 85, '70362': 86, '70217': 87, '62144': 88, '10428': 89, '32519': 90, '10612': 91, '41102': 92, '50618': 93, '32002': 94, '50506': 95, '21002': 96, '62135': 97, '20604': 98, '61251': 99, '50423': 100, '31814': 101, '70825': 102, '31551': 103, '80109': 104, '31204': 105, '61756': 106, '70920': 107, '70504': 108
# }
# Out:
# {'0': 32002, '1': 70706, '2': 70825, '3': 10702, '4': 70709, '5': 61257, '6': 40423, '7': 50617, '8': 32518, '9': 20619, '10': 70504, '11': 61628, '12': 70824, '13': 21002, '14': 80128, '15': 80225, '16': 50612, '17': 41706, '18': 20604, '19': 20914, '20': 80411, '21': 50502, '22': 40702, '23': 70326, '24': 50506, '25': 60350, '26': 30860, '27': 62135, '28': 20622, '29': 70208, '30': 70334, '31': 61756, '32': 31207, '33': 40402, '34': 31652, '35': 70804, '36': 31110, '37': 70406, '38': 61115, '39': 50210, '40': 31916, '41': 40410, '42': 31204, '43': 31814, '44': 41804, '45': 70908, '46': 50206, '47': 70366, '48': 40806, '49': 32210, '50': 32309, '51': 61254, '52': 70516, '53': 10925, '54': 41501, '55': 31405, '56': 20321, '57': 40914, '58': 70402, '59': 10401, '60': 62105, '61': 62390, '62': 50212, '63': 40719, '64': 70217, '65': 41411, '66': 70615, '67': 32519, '68': 31617, '69': 70622, '70': 61627, '71': 41342, '72': 80239, '73': 50618, '74': 50621, '75': 50626, '76': 31035, '77': 90001, '78': 30501, '79': 80105, '80': 40621, '81': 32324, '82': 31551, '83': 50413, '84': 70920, '85': 70221, '86': 31401, '87': 50509, '88': 80212, '89': 80227, '90': 10612, '91': 61032, '92': 70362, '93': 70419, '94': 30719, '95': 70627, '96': 10903, '97': 61743, '98': 80109, '99': 70710, '100': 62144, '101': 10428, '102': 50304, '103': 62216, '104': 70606, '105': 50423, '106': 40605, '107': 70734, '108': 61251, '109': 30910, '110': 41102}

# %% [markdown]
# # Connect encoder ids with labels

# %%
# get max value of the prediction
combined_predictions_max = np.argmax(combined_predictions, axis=1)
#convert combined_predictions_max and targets to accent
combined_predictions_accent = []
for i in combined_predictions_max:
    combined_predictions_accent.append(encoder_dict[str(i)])

combined_targets_accent = []
for i in combined_targets:
    combined_targets_accent.append(encoder_dict[str(i)])

# %% [markdown]
# # Use "Bundesländer" as regions

# %%
region_dict = {}
mapping_regions_dict = {'1': 'bgld', '2': 'ktn', '3': 'noe',
                        '4': 'ooe', '5': 'sbg', '6': 'stmk',
                        '7': 't', '8': 'vbg', '9': 'w'}

unique_accent = set(encoder_dict.values())
for i in unique_accent:
    for j in range(1, len(mapping_regions_dict)+1):  # make loop from 1 to 8 (or 9)
        if str(i)[0] == str(j):
            region_dict[i] = mapping_regions_dict[str(j)]

# map combined_predictions_accent and combined_targets_accent to region
combined_predictions_region = []
for i in combined_predictions_accent:
    combined_predictions_region.append(region_dict[i])
combined_targets_region = []
for i in combined_targets_accent:
    combined_targets_region.append(region_dict[i])

# %% [markdown]
# # Use "Dialektfamilien"

# %%
file_path = '/home/projects/vokquant/data/dicla/DiÖ_PP02_Korpus_Dokumentation_final_Dialaketfamilie.xlsx'
df = pd.read_excel(file_path)

mapping_family_dict = dict(zip(df['Gemeindekennziffer'], df['Dialektfamilie']))
# remove nan
city_code_dict = {k: v for k, v in mapping_family_dict.items() if pd.notna(v)}

# map  combined_predictions_accent and combined_targets_accent to Dialektfamilie
combined_predictions_family = []
for i in combined_predictions_accent:
    combined_predictions_family.append(mapping_family_dict[i])
    
combined_targets_family = []
for i in combined_targets_accent:
    combined_targets_family.append(mapping_family_dict[i])

# Accuracy and F1 score
correct = 0
total = 0
for i in range(len(combined_predictions_family)):
    if combined_predictions_family[i] == combined_targets_family[i]:
        correct += 1
    total += 1
print("Accuracy (Dialektfamilie): ", correct/total)

f1 = f1_score(combined_targets_family, combined_predictions_family, average='weighted')
print("F1 score (Dialektfamilie): ", f1)

unique_values = np.unique(combined_predictions_family)
print("Unique values (Dialektfamilie): ", unique_values)
# print accuarcy per class
print("Accuracy for class: ")
for i in unique_values:
    correct = 0
    total = 0
    for j in range(len(combined_predictions_family)):
        if combined_predictions_family[j] == i and combined_targets_family[j] == i:
            correct += 1
        if combined_targets_family[j] == i:
            total += 1
    #avoid division by zero
    if total == 0:
        print(i, ": ", 0)
    else:
        print(i, ": ", np.round(correct/total, 2))

# confusion_matrix
confusion_matrix = sklearn.metrics.confusion_matrix(combined_targets_family, combined_predictions_family, labels=unique_values)

# add labels to confusion matrix
confusion_matrix = pd.DataFrame(confusion_matrix, index=unique_values, columns=unique_values)
# sort columns and rows by "Alemannisch", "Bairisch-Alemannisch", "Südbairisch", "Süd-/Mittelbairisch", "(West-)Mittelbairisch", "Mittelbairisch"
confusion_matrix = confusion_matrix.reindex(index=["Alemannisch", "Bairisch-Alemannisch", "Südbairisch", "Süd-/Mittelbairisch", "(West-)Mittelbairisch", "Mittelbairisch"], columns=["Alemannisch", "Bairisch-Alemannisch", "Südbairisch", "Süd-/Mittelbairisch", "(West-)Mittelbairisch", "Mittelbairisch"])

# plot confusion matrix
plt.figure(figsize=(4,4))
sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix (Dialektfamilie)')
plt.show()
# Out:
# Accuracy (Dialektfamilie):  0.5993016150152771
# F1 score (Dialektfamilie):  0.6035332116035473
# Unique values (Dialektfamilie):  ['(West-)Mittelbairisch' 'Alemannisch' 'Bairisch-Alemannisch'
#  'Mittelbairisch' 'Süd-/Mittelbairisch' 'Südbairisch']
# Accuracy for class:
# (West-)Mittelbairisch :  0.78
# Alemannisch :  0.62
# Bairisch-Alemannisch :  0
# Mittelbairisch :  0.61
# Süd-/Mittelbairisch :  0.53
# Südbairisch :  0.58

# %%
# now put (West-)Mittelbairisch and Mittelbairisch together
combined_targets_family_together = []
for i in combined_targets_family:
    if i == 'Mittelbairisch' or i == '(West-)Mittelbairisch':
        combined_targets_family_together.append('Mittelbairisch')
    else:
        combined_targets_family_together.append(i)

combined_predictions_family_together = []
for i in combined_predictions_family:
    if i == 'Mittelbairisch' or i == '(West-)Mittelbairisch':
        combined_predictions_family_together.append('Mittelbairisch')
    else:
        combined_predictions_family_together.append(i)
        
# accuracy and F1 score
correct = 0
total = 0
for i in range(len(combined_predictions_family_together)):
    if combined_predictions_family_together[i] == combined_targets_family_together[i]:
        correct += 1
    total += 1
print("Accuracy (Dialektfamilie): ", correct/total)

f1 = f1_score(combined_targets_family_together, combined_predictions_family_together, average='weighted')
print("F1 score (Dialektfamilie): ", f1)
unique_values_together = np.unique(combined_predictions_family_together)

# print accuracy per Dialektfamilie
# print("Accuracy (Dialektfamilie): ")
# for i in unique_values_together:
#     correct = 0
#     total = 0
#     for j in range(len(combined_predictions_family_together)):
#         if combined_predictions_family_together[j] == combined_targets_family_together[j] and combined_targets_family_together[j] == i:
#             correct += 1
#         if combined_targets_family_together[j] == i:
#             total += 1
#     print(i, ": ", correct/total, " (", total, " samples)")
# confusion_matrix
confusion_matrix = sklearn.metrics.confusion_matrix(combined_targets_family_together, combined_predictions_family_together, labels=unique_values_together)

# add labels to confusion matrix
confusion_matrix = pd.DataFrame(confusion_matrix, index=unique_values_together, columns=unique_values_together)
# sort columns and rows by "Alemannisch", "Südbairisch", "Süd-/Mittelbairisch", "(West-)Mittelbairisch", "Mittelbairisch"
confusion_matrix = confusion_matrix.reindex(index=["Alemannisch", "Bairisch-Alemannisch", "Südbairisch", "Süd-/Mittelbairisch", "Mittelbairisch"], columns=["Alemannisch", "Bairisch-Alemannisch", "Südbairisch", "Süd-/Mittelbairisch", "Mittelbairisch"])

# plot confusion matrix
plt.figure(figsize=(4,4))
sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix (Dialektfamilie ohne (West-)Mittelbairisch)')
plt.show()
# Out:
# Accuracy (Dialektfamilie):  0.6545176778699258
# F1 score (Dialektfamilie):  0.6549615653839961

# %% [markdown]
# # Calculate Statistics

# %%
# calculate per accent
correct = 0
distance_error = 0
for i in range(len(combined_predictions_accent)):
    if combined_predictions_accent[i] == combined_targets_accent[i]:
        correct += 1
accuracy_region = correct/len(combined_predictions_accent)
f1_region = f1_score(combined_targets_accent, combined_predictions_accent, average='weighted')
#{'micro', 'weighted', 'binary', 'samples', 'macro'}
print("Accuracy per village: ", np.round(accuracy_region, 3))
print("F1 score per village: ", np.round(f1_region, 3))

# calculate accuracy
correct = 0
for i in range(len(combined_predictions_region)):
    if combined_predictions_region[i] == combined_targets_region[i]:
        correct += 1
accuracy = correct/len(combined_predictions_region)
print("Accuracy per Bundesland: ", np.round(accuracy, 3))

f1 = f1_score(combined_targets_region, combined_predictions_region, average='weighted')
print("F1 score per Bundesland: ", np.round(f1, 3))
# print accuracy per Bundesland
unique_values = np.unique(combined_targets_region)
print("Accuracy per Bundesland:")

for i in unique_values:
    correct = 0
    total = 0
    for j in range(len(combined_targets_region)):
        if combined_targets_region[j] == i:
            total += 1
            if combined_predictions_region[j] == i:
                correct += 1
    accuracy = correct/total
    # print separate by tab
    print(i, "\t", np.round(accuracy, 2))
    
confusion_matrix = sklearn.metrics.confusion_matrix(combined_targets_region, combined_predictions_region)
# sort from West to East

# Add labels to confusion matrix
df_cm = pd.DataFrame(confusion_matrix, index=[i for i in mapping_regions_dict.values()],
                     columns=[i for i in mapping_regions_dict.values()])

plt.figure(figsize=(10,7))

# Use `fmt='d'` in the heatmap to display the annotations as integers instead of scientific notation
sns.heatmap(df_cm, annot=True, fmt='d', cmap='Blues')

# Plot titles and labels
plt.xlabel('Predicted Region')
plt.ylabel('True Region')
plt.title('Confusion Matrix')

# Display the heatmap
plt.show()
# Out:
# Accuracy per village:  0.166
# F1 score per village:  0.19
# Accuracy per Bundesland:  0.423
# F1 score per Bundesland:  0.422
# Accuracy per Bundesland:
# bgld 	 0.1
# ktn 	 0.67
# noe 	 0.59
# ooe 	 0.52
# sbg 	 0.17
# stmk 	 0.36
# t 	 0.65
# vbg 	 0.62
# w 	 0.2

# %%
# add /home/projects/vokquant/accent-recog-slt2022/CommonAccent/ to path
import sys
sys.path.append('/home/projects/vokquant/accent-recog-slt2022/CommonAccent/accent_id/')
from train_w2v2_hav_mms import haversine
import pandas as pd
gemeinde_csv = "/home/projects/vokquant/accent-recog-slt2022/CommonAccent/data/gemeinde_coordinates.csv"
gemeinde_df = pd.read_csv(gemeinde_csv)


# distance = haversine(lat1, lon1, lat2, lon2)

def get_distance(prediction, target):
    lat1 = gemeinde_df[gemeinde_df['Gemeindekennzahl'] == int(target)]['Latitude'].values[0]
    lon1 = gemeinde_df[gemeinde_df['Gemeindekennzahl'] == int(target)]['Longitude'].values[0]
    lat2 = gemeinde_df[gemeinde_df['Gemeindekennzahl'] == int(prediction)]['Latitude'].values[0]
    lon2 = gemeinde_df[gemeinde_df['Gemeindekennzahl'] == int(prediction)]['Longitude'].values[0]
    return haversine(lat1, lon1, lat2, lon2)
    
# calculate per accent
correct = 0
distance_error = 0
for i in range(len(combined_predictions_accent)):
    if combined_predictions_accent[i] == combined_targets_accent[i]:
        correct += 1
        distance_error_tmp = 0
        distance_error += distance_error_tmp
    else:
        distance_error_tmp = get_distance(combined_predictions_accent[i], combined_targets_accent[i])
        distance_error += distance_error_tmp
        print("Distance error per example: ", distance_error_tmp)
        # if distance_error_tmp > 400:
        #     print("Prediction: ", gemeinde_df[gemeinde_df['Gemeindekennzahl'] == int(combined_predictions_accent[i])])
        #     print("Target: ", gemeinde_df[gemeinde_df['Gemeindekennzahl'] == int(combined_targets_accent[i])])
            
print("Distance error: ", distance_error)
print("average distance error: ", distance_error/len(combined_predictions_accent))
# Out:
# Distance error per example:  32.8617965392038
# Distance error per example:  509.4791318528689
# Distance error per example:  32.8617965392038
# Distance error per example:  327.87414394534426
# Distance error per example:  227.39804444128302
# Distance error per example:  88.45011428531748
# Distance error per example:  500.5942046496184
# Distance error per example:  32.8617965392038
# Distance error per example:  178.46814758843766
# Distance error per example:  131.70442603048687
# Distance error per example:  194.58107245520694
# Distance error per example:  57.33277449344782
# Distance error per example:  33.061677158543894
# Distance error per example:  224.72007060619708
# Distance error per example:  307.83181909939435
# Distance error per example:  75.27211879174837
# Distance error per example:  128.6197244049999
# Distance error per example:  26.867820386032488
# Distance error per example:  87.44424924550722
# Distance error per example:  256.8821614515557
# Distance error per example:  193.6058982832319
# Distance error per example:  123.21488037787299
# Distance error per example:  46.84750561035332
# Distance error per example:  183.8732068939072
# Distance error per example:  32.8617965392038
# Distance error per example:  32.8617965392038
# Distance error per example:  197.0243935427239
# Distance error per example:  227.39804444128302
# Distance error per example:  307.83181909939435
# Distance error per example:  32.8617965392038
# Distance error per example:  16.370799498034835
# Distance error per example:  32.8617965392038
# Distance error per example:  32.8617965392038
# Distance error per example:  22.05643710545692
# Distance error per example:  32.8617965392038
# Distance error per example:  122.92128934587984
# Distance error per example:  227.39804444128302
# Distance error per example:  248.76242931027676
# Distance error per example:  110.9402110827567
# Distance error per example:  110.9402110827567
# Distance error per example:  194.58107245520694
# Distance error per example:  136.61678202349142
# Distance error per example:  114.25711417684506
# Distance error per example:  111.50388097040104
# Distance error per example:  46.84750561035332
# Distance error per example:  26.867820386032488
# Distance error per example:  232.03279538333038
# Distance error per example:  183.8732068939072
# Distance error per example:  16.370799498034835
# Distance error per example:  309.19223715254884
# Distance error per example:  167.23359663093368
# Distance error per example:  46.84750561035332
# Distance error per example:  22.05643710545692
# Distance error per example:  95.22929061762252
# Distance error per example:  34.388298309202305
# Distance error per example:  138.33125870701363
# Distance error per example:  51.75739065832323
# Distance error per example:  32.8617965392038
# Distance error per example:  32.8617965392038
# Distance error per example:  327.87414394534426
# Distance error per example:  84.07877774896934
# Distance error per example:  95.21516424641585
# Distance error per example:  181.3290518569431
# Distance error per example:  23.72137529940561
# Distance error per example:  51.72668836301636
# Distance error per example:  34.388298309202305
# Distance error per example:  23.72137529940561
# Distance error per example:  282.31387059515646
# Distance error per example:  63.06048069989546
# Distance error per example:  83.88978441401288
# Distance error per example:  123.21488037787299
# Distance error per example:  167.23359663093368
# Distance error per example:  37.65587420214649
# Distance error per example:  397.0080473821925
# Distance error per example:  37.65587420214649
# Distance error per example:  123.21488037787299
# Distance error per example:  97.75071483360097
# Distance error per example:  120.56343577155987
# Distance error per example:  233.81044759491107
# Distance error per example:  77.60475227882019
# Distance error per example:  21.091774062173833
# Distance error per example:  110.9402110827567
# Distance error per example:  242.0574742241637
# Distance error per example:  129.58718079457805
# Distance error per example:  31.04507606953544
# Distance error per example:  80.86389867584903
# Distance error per example:  157.69582476596526
# Distance error per example:  279.43075250701816
# Distance error per example:  198.2267578442989
# Distance error per example:  93.54387479181077
# Distance error per example:  17.481974638222354
# Distance error per example:  37.136331680448585
# Distance error per example:  93.54387479181077
# Distance error per example:  79.68066059596904
# Distance error per example:  32.01392510677986
# Distance error per example:  51.72668836301636
# Distance error per example:  500.5942046496184
# Distance error per example:  157.67244415938984
# Distance error per example:  214.97168922886434
# Distance error per example:  338.3720488748812
# Distance error per example:  214.97168922886434
# Distance error per example:  167.72171490591066
# Distance error per example:  56.273619417335524
# Distance error per example:  51.75739065832323
# Distance error per example:  167.74392953979697
# Distance error per example:  131.7815185824692
# Distance error per example:  140.14346933443855
# Distance error per example:  92.7114683987401
# Distance error per example:  95.22929061762252
# Distance error per example:  104.23536380824734
# Distance error per example:  362.8730949858343
# Distance error per example:  16.370799498034835
# Distance error per example:  22.74693116919119
# Distance error per example:  20.752330875757327
# Distance error per example:  51.75739065832323
# Distance error per example:  142.2277994700893
# Distance error per example:  352.1769586510979
# Distance error per example:  352.1769586510979
# Distance error per example:  155.5341400796622
# Distance error per example:  502.29234661698507
# Distance error per example:  95.07843109001963
# Distance error per example:  16.370799498034835
# Distance error per example:  146.561400117331
# Distance error per example:  225.70778496648214
# Distance error per example:  16.370799498034835
# Distance error per example:  16.370799498034835
# Distance error per example:  22.05643710545692
# Distance error per example:  171.5624467941342
# Distance error per example:  215.74844502348802
# Distance error per example:  214.97168922886434
# Distance error per example:  214.97168922886434
# Distance error per example:  228.0866241686062
# Distance error per example:  227.39804444128302
# Distance error per example:  33.061677158543894
# Distance error per example:  32.96047094573555
# Distance error per example:  32.01392510677986
# Distance error per example:  29.585884774911154
# Distance error per example:  209.44500775834257
# Distance error per example:  92.7114683987401
# Distance error per example:  156.06334943313038
# Distance error per example:  95.22929061762252
# Distance error per example:  55.65477817096692
# Distance error per example:  178.22857337515563
# Distance error per example:  121.90572522979254
# Distance error per example:  125.73153752370102
# Distance error per example:  120.35276132847913
# Distance error per example:  49.77695129696436
# Distance error per example:  283.5107479450668
# Distance error per example:  306.4875270559108
# Distance error per example:  125.02634686377345
# Distance error per example:  193.0380219357578
# Distance error per example:  535.0151198383302
# Distance error per example:  33.061677158543894
# Distance error per example:  119.65651307884397
# Distance error per example:  80.35680218866335
# Distance error per example:  242.2347173303
# Distance error per example:  32.01392510677986
# Distance error per example:  251.33319939094588
# Distance error per example:  100.5146949384109
# Distance error per example:  41.078596898637464
# Distance error per example:  58.538082612167095
# Distance error per example:  280.16069057676106
# Distance error per example:  90.99985835392673
# Distance error per example:  80.86389867584903
# Distance error per example:  57.98293472307952
# Distance error per example:  522.9553608760868
# Distance error per example:  62.98326807088395
# Distance error per example:  56.26066694616735
# Distance error per example:  20.752330875757327
# Distance error per example:  88.45011428531748
# Distance error per example:  116.44646244572222
# Distance error per example:  309.19223715254884
# Distance error per example:  158.4676212458365
# Distance error per example:  80.35680218866335
# Distance error per example:  32.01392510677986
# Distance error per example:  107.66312523491774
# Distance error per example:  99.88195901564748
# Distance error per example:  83.24542791326279
# Distance error per example:  227.767169624181
# Distance error per example:  214.97168922886434
# Distance error per example:  227.39804444128302
# Distance error per example:  84.07877774896934
# Distance error per example:  222.8828344090194
# Distance error per example:  163.07718216676832
# Distance error per example:  22.05643710545692
# Distance error per example:  57.403960315035334
# Distance error per example:  119.65651307884397
# Distance error per example:  222.00716923531542
# Distance error per example:  7.03835339535748
# Distance error per example:  18.854697826074908
# Distance error per example:  49.38523532425377
# Distance error per example:  83.7275817577659
# Distance error per example:  107.93562734471458
# Distance error per example:  436.5966258889825
# Distance error per example:  23.72137529940561
# Distance error per example:  119.65651307884397
# Distance error per example:  22.05643710545692
# Distance error per example:  52.17952461563766
# Distance error per example:  34.388298309202305
# Distance error per example:  33.061677158543894
# Distance error per example:  85.99787706991125
# Distance error per example:  177.61420727973731
# Distance error per example:  17.481974638222354
# Distance error per example:  262.33555890624893
# Distance error per example:  116.87983427653202
# Distance error per example:  105.49382855857702
# Distance error per example:  436.26987741146684
# Distance error per example:  509.4791318528689
# Distance error per example:  131.70442603048687
# Distance error per example:  107.93562734471458
# Distance error per example:  32.8617965392038
# Distance error per example:  77.46618943249985
# Distance error per example:  509.4791318528689
# Distance error per example:  509.4791318528689
# Distance error per example:  32.8617965392038
# Distance error per example:  214.97168922886434
# Distance error per example:  193.6058982832319
# Distance error per example:  215.17107031067744
# Distance error per example:  50.438366418973374
# Distance error per example:  33.061677158543894
# Distance error per example:  109.55706038219977
# Distance error per example:  22.05643710545692
# Distance error per example:  80.35680218866335
# Distance error per example:  33.061677158543894
# Distance error per example:  111.7482675872665
# Distance error per example:  358.1164434410888
# Distance error per example:  193.6058982832319
# Distance error per example:  192.3434312168312
# Distance error per example:  95.22929061762252
# Distance error per example:  349.0199983363772
# Distance error per example:  63.06048069989546
# Distance error per example:  16.370799498034835
# Distance error per example:  193.6058982832319
# Distance error per example:  22.05643710545692
# Distance error per example:  114.25711417684506
# Distance error per example:  16.370799498034835
# Distance error per example:  22.05643710545692
# Distance error per example:  22.05643710545692
# Distance error per example:  193.6058982832319
# Distance error per example:  22.05643710545692
# Distance error per example:  80.35680218866335
# Distance error per example:  32.8617965392038
# Distance error per example:  32.8617965392038
# Distance error per example:  214.97168922886434
# Distance error per example:  100.12964764883306
# Distance error per example:  22.05643710545692
# Distance error per example:  34.388298309202305
# Distance error per example:  131.70442603048687
# Distance error per example:  323.7445514786022
# Distance error per example:  362.8730949858343
# Distance error per example:  94.3312076951919
# Distance error per example:  34.388298309202305
# Distance error per example:  303.02235418687957
# Distance error per example:  104.23536380824734
# Distance error per example:  90.94795559563269
# Distance error per example:  26.867820386032488
# Distance error per example:  26.867820386032488
# Distance error per example:  33.061677158543894
# Distance error per example:  378.0017898430303
# Distance error per example:  45.35515755423418
# Distance error per example:  158.4676212458365
# Distance error per example:  75.14002315356447
# Distance error per example:  131.1453984116416
# Distance error per example:  191.10448042713708
# Distance error per example:  41.078596898637464
# Distance error per example:  46.84750561035332
# Distance error per example:  171.06471851148737
# Distance error per example:  214.97168922886434
# Distance error per example:  32.8617965392038
# Distance error per example:  176.0799051303233
# Distance error per example:  32.8617965392038
# Distance error per example:  108.85673251383064
# Distance error per example:  279.43075250701816
# Distance error per example:  29.195251115203803
# Distance error per example:  143.14055411971233
# Distance error per example:  233.81044759491107
# Distance error per example:  105.49382855857702
# Distance error per example:  57.403960315035334
# Distance error per example:  227.39804444128302
# Distance error per example:  94.70237623864534
# Distance error per example:  146.65698717346578
# Distance error per example:  26.867820386032488
# Distance error per example:  119.65651307884397
# Distance error per example:  242.0574742241637
# Distance error per example:  99.8302862269251
# Distance error per example:  116.59808246907743
# Distance error per example:  254.11927884956393
# Distance error per example:  33.061677158543894
# Distance error per example:  70.17539982736145
# Distance error per example:  33.061677158543894
# Distance error per example:  105.49382855857702
# Distance error per example:  137.66406685294362
# Distance error per example:  233.81044759491107
# Distance error per example:  46.84750561035332
# Distance error per example:  137.66406685294362
# Distance error per example:  57.403960315035334
# Distance error per example:  137.66406685294362
# Distance error per example:  34.388298309202305
# Distance error per example:  34.388298309202305
# Distance error per example:  83.24542791326279
# Distance error per example:  32.8617965392038
# Distance error per example:  157.90635858655955
# Distance error per example:  227.39804444128302
# Distance error per example:  83.24542791326279
# Distance error per example:  32.8617965392038
# Distance error per example:  143.614093897953
# Distance error per example:  214.97168922886434
# Distance error per example:  32.8617965392038
# Distance error per example:  27.10554915610642
# Distance error per example:  77.60475227882019
# Distance error per example:  116.87983427653202
# Distance error per example:  18.99571009855775
# Distance error per example:  87.44424924550722
# Distance error per example:  183.65605255184897
# Distance error per example:  23.72137529940561
# Distance error per example:  34.388298309202305
# Distance error per example:  251.33319939094588
# Distance error per example:  49.77695129696436
# Distance error per example:  254.11927884956393
# Distance error per example:  92.7114683987401
# Distance error per example:  217.73410332832867
# Distance error per example:  18.854697826074908
# Distance error per example:  123.21488037787299
# Distance error per example:  55.7064141387438
# Distance error per example:  133.5938675574443
# Distance error per example:  55.65477817096692
# Distance error per example:  401.59411396893967
# Distance error per example:  32.01392510677986
# Distance error per example:  280.16069057676106
# Distance error per example:  436.5966258889825
# Distance error per example:  214.97168922886434
# Distance error per example:  214.97168922886434
# Distance error per example:  280.16069057676106
# Distance error per example:  500.5942046496184
# Distance error per example:  32.8617965392038
# Distance error per example:  227.39804444128302
# Distance error per example:  99.88195901564748
# Distance error per example:  33.061677158543894
# Distance error per example:  22.05643710545692
# Distance error per example:  420.9262556814472
# Distance error per example:  59.05339795698285
# Distance error per example:  83.7275817577659
# Distance error per example:  107.66312523491774
# Distance error per example:  125.73153752370102
# Distance error per example:  37.65587420214649
# Distance error per example:  259.3620793675587
# Distance error per example:  167.0228945791014
# Distance error per example:  92.7114683987401
# Distance error per example:  36.934520114334845
# Distance error per example:  111.7482675872665
# Distance error per example:  227.44052702951592
# Distance error per example:  51.75739065832323
# Distance error per example:  259.3620793675587
# Distance error per example:  273.93392849653685
# Distance error per example:  32.01392510677986
# Distance error per example:  177.19857816357236
# Distance error per example:  127.02268518331452
# Distance error per example:  123.21488037787299
# Distance error per example:  107.66312523491774
# Distance error per example:  29.585884774911154
# Distance error per example:  32.96047094573555
# Distance error per example:  143.14055411971233
# Distance error per example:  251.33319939094588
# Distance error per example:  200.63588879260973
# Distance error per example:  183.48480195554643
# Distance error per example:  108.85673251383064
# Distance error per example:  199.86920771359414
# Distance error per example:  174.56914410608152
# Distance error per example:  156.69024567606223
# Distance error per example:  32.8617965392038
# Distance error per example:  227.39804444128302
# Distance error per example:  32.96047094573555
# Distance error per example:  33.84418282546496
# Distance error per example:  120.2802321751301
# Distance error per example:  45.35515755423418
# Distance error per example:  26.867820386032488
# Distance error per example:  198.2267578442989
# Distance error per example:  259.3620793675587
# Distance error per example:  94.00431921815232
# Distance error per example:  72.36747607853604
# Distance error per example:  224.37838918512026
# Distance error per example:  107.66312523491774
# Distance error per example:  119.5881359544509
# Distance error per example:  22.572524194925663
# Distance error per example:  85.61533769158224
# Distance error per example:  125.73153752370102
# Distance error per example:  326.2029078242937
# Distance error per example:  227.39804444128302
# Distance error per example:  500.5942046496184
# Distance error per example:  23.663317049552543
# Distance error per example:  7.03835339535748
# Distance error per example:  50.930942469451054
# Distance error per example:  125.02634686377345
# Distance error per example:  77.60475227882019
# Distance error per example:  125.02634686377345
# Distance error per example:  215.17107031067744
# Distance error per example:  44.46044525900244
# Distance error per example:  126.99673902186125
# Distance error per example:  80.35680218866335
# Distance error per example:  23.72137529940561
# Distance error per example:  84.07877774896934
# Distance error per example:  7.03835339535748
# Distance error per example:  87.44424924550722
# Distance error per example:  111.03003951291933
# Distance error per example:  156.06334943313038
# Distance error per example:  203.06575283239675
# Distance error per example:  37.962736080988705
# Distance error per example:  283.5107479450668
# Distance error per example:  75.14002315356447
# Distance error per example:  197.8060402364497
# Distance error per example:  57.403960315035334
# Distance error per example:  23.149958274053233
# Distance error per example:  33.37673478184292
# Distance error per example:  95.22929061762252
# Distance error per example:  193.70847491760856
# Distance error per example:  326.2029078242937
# Distance error per example:  107.66312523491774
# Distance error per example:  76.64512170322112
# Distance error per example:  22.572524194925663
# Distance error per example:  435.77880360750646
# Distance error per example:  76.64512170322112
# Distance error per example:  92.24979766366252
# Distance error per example:  22.05643710545692
# Distance error per example:  535.0151198383302
# Distance error per example:  525.3986240635594
# Distance error per example:  11.58656847788744
# Distance error per example:  100.12964764883306
# Distance error per example:  164.96072627439074
# Distance error per example:  105.49382855857702
# Distance error per example:  110.9402110827567
# Distance error per example:  120.2802321751301
# Distance error per example:  22.05643710545692
# Distance error per example:  94.3312076951919
# Distance error per example:  34.388298309202305
# Distance error per example:  107.93562734471458
# Distance error per example:  72.36747607853604
# Distance error per example:  280.16069057676106
# Distance error per example:  17.481974638222354
# Distance error per example:  280.16069057676106
# Distance error per example:  93.54387479181077
# Distance error per example:  17.481974638222354
# Distance error per example:  116.6924642840104
# Distance error per example:  49.77695129696436
# Distance error per example:  95.21516424641585
# Distance error per example:  94.3312076951919
# Distance error per example:  107.66312523491774
# Distance error per example:  280.16069057676106
# Distance error per example:  7.03835339535748
# Distance error per example:  133.3837552474078
# Distance error per example:  364.66771694715334
# Distance error per example:  22.05643710545692
# Distance error per example:  525.3986240635594
# Distance error per example:  500.5942046496184
# Distance error per example:  227.39804444128302
# Distance error per example:  227.39804444128302
# Distance error per example:  87.84856377161945
# Distance error per example:  50.930942469451054
# Distance error per example:  32.8617965392038
# Distance error per example:  16.370799498034835
# Distance error per example:  119.65651307884397
# Distance error per example:  116.6924642840104
# Distance error per example:  131.14530322026582
# Distance error per example:  174.56914410608152
# Distance error per example:  171.06471851148737
# Distance error per example:  33.061677158543894
# Distance error per example:  22.05643710545692
# Distance error per example:  22.05643710545692
# Distance error per example:  354.73561048167744
# Distance error per example:  51.75739065832323
# Distance error per example:  22.74693116919119
# Distance error per example:  22.05643710545692
# Distance error per example:  107.66312523491774
# Distance error per example:  44.46044525900244
# Distance error per example:  245.61794531697484
# Distance error per example:  11.544306383114913
# Distance error per example:  72.36747607853604
# Distance error per example:  227.39804444128302
# Distance error per example:  120.2802321751301
# Distance error per example:  26.867820386032488
# Distance error per example:  488.80359868140914
# Distance error per example:  500.5942046496184
# Distance error per example:  26.867820386032488
# Distance error per example:  280.16069057676106
# Distance error per example:  500.5942046496184
# Distance error per example:  192.3434312168312
# Distance error per example:  131.70442603048687
# Distance error per example:  94.70237623864534
# Distance error per example:  192.67884600024615
# Distance error per example:  34.388298309202305
# Distance error per example:  211.23861145303866
# Distance error per example:  107.66312523491774
# Distance error per example:  84.07877774896934
# Distance error per example:  156.06334943313038
# Distance error per example:  397.0080473821925
# Distance error per example:  358.1164434410888
# Distance error per example:  22.05643710545692
# Distance error per example:  280.16069057676106
# Distance error per example:  214.97168922886434
# Distance error per example:  45.35515755423418
# Distance error per example:  77.23996119875174
# Distance error per example:  43.111294569789216
# Distance error per example:  100.5146949384109
# Distance error per example:  313.85931080938985
# Distance error per example:  509.4791318528689
# Distance error per example:  33.967090714813665
# Distance error per example:  33.84418282546496
# Distance error per example:  266.67265665453726
# Distance error per example:  43.111294569789216
# Distance error per example:  309.19223715254884
# Distance error per example:  100.00990773522749
# Distance error per example:  18.854697826074908
# Distance error per example:  22.05643710545692
# Distance error per example:  309.19223715254884
# Distance error per example:  420.9262556814472
# Distance error per example:  137.76164463701556
# Distance error per example:  45.35515755423418
# Distance error per example:  56.26066694616735
# Distance error per example:  7.03835339535748
# Distance error per example:  54.931240207025766
# Distance error per example:  45.931585288873336
# Distance error per example:  28.276522767854008
# Distance error per example:  95.78557865606028
# Distance error per example:  44.46044525900244
# Distance error per example:  146.561400117331
# Distance error per example:  143.14055411971233
# Distance error per example:  232.03279538333038
# Distance error per example:  22.572524194925663
# Distance error per example:  116.44646244572222
# Distance error per example:  87.84856377161945
# Distance error per example:  32.8617965392038
# Distance error per example:  60.265603369692585
# Distance error per example:  39.9458331929572
# Distance error per example:  157.67244415938984
# Distance error per example:  198.2267578442989
# Distance error per example:  134.1463601437653
# Distance error per example:  190.82685113477416
# Distance error per example:  233.81044759491107
# Distance error per example:  436.5966258889825
# Distance error per example:  486.56505700322475
# Distance error per example:  251.33319939094588
# Distance error per example:  70.17539982736145
# Distance error per example:  233.81044759491107
# Distance error per example:  89.35650150141625
# Distance error per example:  26.867820386032488
# Distance error per example:  29.585884774911154
# Distance error per example:  178.46814758843766
# Distance error per example:  177.19857816357236
# Distance error per example:  95.22929061762252
# Distance error per example:  154.10355820827024
# Distance error per example:  140.14346933443855
# Distance error per example:  183.48480195554643
# Distance error per example:  92.7114683987401
# Distance error per example:  254.11927884956393
# Distance error per example:  126.99673902186125
# Distance error per example:  185.36821042736725
# Distance error per example:  156.06334943313038
# Distance error per example:  92.24979766366252
# Distance error per example:  92.24979766366252
# Distance error per example:  338.3720488748812
# Distance error per example:  530.6371390527935
# Distance error per example:  28.276522767854008
# Distance error per example:  131.70442603048687
# Distance error per example:  55.7064141387438
# Distance error per example:  34.388298309202305
# Distance error per example:  199.86920771359414
# Distance error per example:  372.5362213242132
# Distance error per example:  70.17539982736145
# Distance error per example:  307.83181909939435
# Distance error per example:  57.403960315035334
# Distance error per example:  157.86100022159513
# Distance error per example:  86.39591446480846
# Distance error per example:  254.11927884956393
# Distance error per example:  233.81044759491107
# Distance error per example:  163.07718216676832
# Distance error per example:  70.17539982736145
# Distance error per example:  94.70237623864534
# Distance error per example:  56.26066694616735
# Distance error per example:  157.86100022159513
# Distance error per example:  232.59173245051144
# Distance error per example:  70.17539982736145
# Distance error per example:  137.66406685294362
# Distance error per example:  152.2271042991705
# Distance error per example:  171.5624467941342
# Distance error per example:  123.21488037787299
# Distance error per example:  95.21516424641585
# Distance error per example:  22.05643710545692
# Distance error per example:  22.05643710545692
# Distance error per example:  110.9402110827567
# Distance error per example:  33.061677158543894
# Distance error per example:  22.05643710545692
# Distance error per example:  283.5107479450668
# Distance error per example:  32.8617965392038
# Distance error per example:  227.39804444128302
# Distance error per example:  156.06334943313038
# Distance error per example:  22.05643710545692
# Distance error per example:  125.73153752370102
# Distance error per example:  198.2267578442989
# Distance error per example:  22.05643710545692
# Distance error per example:  80.86389867584903
# Distance error per example:  372.5362213242132
# Distance error per example:  107.66312523491774
# Distance error per example:  143.14055411971233
# Distance error per example:  421.5941545644055
# Distance error per example:  56.273619417335524
# Distance error per example:  98.40190131840524
# Distance error per example:  42.29554218436894
# Distance error per example:  31.04507606953544
# Distance error per example:  252.7881927021463
# Distance error per example:  161.62455276136274
# Distance error per example:  397.0080473821925
# Distance error per example:  120.35276132847913
# Distance error per example:  33.061677158543894
# Distance error per example:  247.73782536149707
# Distance error per example:  43.98353460767704
# Distance error per example:  183.8732068939072
# Distance error per example:  32.01392510677986
# Distance error per example:  209.44500775834257
# Distance error per example:  75.14002315356447
# Distance error per example:  80.35680218866335
# Distance error per example:  37.962736080988705
# Distance error per example:  71.35800807830522
# Distance error per example:  131.01395812595752
# Distance error per example:  436.5966258889825
# Distance error per example:  32.8617965392038
# Distance error per example:  51.75739065832323
# Distance error per example:  32.8617965392038
# Distance error per example:  509.4791318528689
# Distance error per example:  60.02217439870451
# Distance error per example:  309.66490921249215
# Distance error per example:  77.60475227882019
# Distance error per example:  98.40190131840524
# Distance error per example:  185.79962961737294
# Distance error per example:  32.01392510677986
# Distance error per example:  113.89491514149832
# Distance error per example:  71.27671121845277
# Distance error per example:  157.69582476596526
# Distance error per example:  22.572524194925663
# Distance error per example:  121.33345674256006
# Distance error per example:  44.43683203159418
# Distance error per example:  37.65587420214649
# Distance error per example:  32.01392510677986
# Distance error per example:  37.962736080988705
# Distance error per example:  177.66536916892971
# Distance error per example:  279.43075250701816
# Distance error per example:  128.6197244049999
# Distance error per example:  125.02634686377345
# Distance error per example:  183.65605255184897
# Distance error per example:  51.72668836301636
# Distance error per example:  193.70847491760856
# Distance error per example:  420.9262556814472
# Distance error per example:  90.94795559563269
# Distance error per example:  170.68577048788686
# Distance error per example:  80.86389867584903
# Distance error per example:  37.962736080988705
# Distance error per example:  95.21516424641585
# Distance error per example:  112.32008707708249
# Distance error per example:  72.36747607853604
# Distance error per example:  95.22929061762252
# Distance error per example:  193.6058982832319
# Distance error per example:  137.66406685294362
# Distance error per example:  32.8617965392038
# Distance error per example:  227.39804444128302
# Distance error per example:  500.5942046496184
# Distance error per example:  62.98326807088395
# Distance error per example:  58.51212375959558
# Distance error per example:  18.911281481671534
# Distance error per example:  44.46044525900244
# Distance error per example:  80.35680218866335
# Distance error per example:  242.0574742241637
# Distance error per example:  18.911281481671534
# Distance error per example:  17.481974638222354
# Distance error per example:  49.38523532425377
# Distance error per example:  76.64512170322112
# Distance error per example:  32.01392510677986
# Distance error per example:  280.16069057676106
# Distance error per example:  158.9094281142221
# Distance error per example:  57.98293472307952
# Distance error per example:  98.12098752507586
# Distance error per example:  95.22929061762252
# Distance error per example:  32.8617965392038
# Distance error per example:  94.3312076951919
# Distance error per example:  214.97168922886434
# Distance error per example:  32.8617965392038
# Distance error per example:  92.7114683987401
# Distance error per example:  259.3620793675587
# Distance error per example:  436.5966258889825
# Distance error per example:  193.6058982832319
# Distance error per example:  93.54387479181077
# Distance error per example:  90.99985835392673
# Distance error per example:  33.061677158543894
# Distance error per example:  156.06334943313038
# Distance error per example:  280.16069057676106
# Distance error per example:  120.56343577155987
# Distance error per example:  32.01392510677986
# Distance error per example:  32.01392510677986
# Distance error per example:  59.93392137581755
# Distance error per example:  92.24979766366252
# Distance error per example:  76.634151739773
# Distance error per example:  284.4149369177825
# Distance error per example:  235.71187254806262
# Distance error per example:  137.04388114444183
# Distance error per example:  108.63374101440134
# Distance error per example:  66.90299789087156
# Distance error per example:  95.22929061762252
# Distance error per example:  120.56343577155987
# Distance error per example:  124.22922945137817
# Distance error per example:  57.403960315035334
# Distance error per example:  33.061677158543894
# Distance error per example:  95.22929061762252
# Distance error per example:  323.7445514786022
# Distance error per example:  173.94950256150278
# Distance error per example:  323.7445514786022
# Distance error per example:  125.73153752370102
# Distance error per example:  105.12065061088796
# Distance error per example:  33.061677158543894
# Distance error per example:  227.39804444128302
# Distance error per example:  49.38523532425377
# Distance error per example:  32.8617965392038
# Distance error per example:  500.5942046496184
# Distance error per example:  171.06471851148737
# Distance error per example:  492.95213997613456
# Distance error per example:  58.068416703169795
# Distance error per example:  37.962736080988705
# Distance error per example:  15.674402040568044
# Distance error per example:  314.164994686793
# Distance error per example:  37.962736080988705
# Distance error per example:  189.3221647028213
# Distance error per example:  110.79551375130771
# Distance error per example:  102.49592868793906
# Distance error per example:  7.03835339535748
# Distance error per example:  384.3182877969654
# Distance error per example:  90.56160779239458
# Distance error per example:  33.061677158543894
# Distance error per example:  39.16777036825698
# Distance error per example:  131.28045343028674
# Distance error per example:  156.06334943313038
# Distance error per example:  150.69625564443356
# Distance error per example:  11.544306383114913
# Distance error per example:  49.77695129696436
# Distance error per example:  7.03835339535748
# Distance error per example:  214.97168922886434
# Distance error per example:  214.97168922886434
# Distance error per example:  500.5942046496184
# Distance error per example:  214.97168922886434
# Distance error per example:  75.6376140265619
# Distance error per example:  279.43075250701816
# Distance error per example:  107.93562734471458
# Distance error per example:  32.01392510677986
# Distance error per example:  51.75739065832323
# Distance error per example:  175.4962348849433
# Distance error per example:  177.19857816357236
# Distance error per example:  91.44793352575839
# Distance error per example:  362.6227503511039
# Distance error per example:  269.25604135647177
# Distance error per example:  94.3312076951919
# Distance error per example:  309.19223715254884
# Distance error per example:  22.572524194925663
# Distance error per example:  157.0801298435918
# Distance error per example:  158.9094281142221
# Distance error per example:  52.17952461563766
# Distance error per example:  143.14055411971233
# Distance error per example:  278.010802337371
# Distance error per example:  176.1996101110795
# Distance error per example:  56.273619417335524
# Distance error per example:  167.23359663093368
# Distance error per example:  32.01392510677986
# Distance error per example:  171.06471851148737
# Distance error per example:  110.9402110827567
# Distance error per example:  22.05643710545692
# Distance error per example:  158.9094281142221
# Distance error per example:  22.05643710545692
# Distance error per example:  22.05643710545692
# Distance error per example:  45.931585288873336
# Distance error per example:  7.03835339535748
# Distance error per example:  22.05643710545692
# Distance error per example:  76.64512170322112
# Distance error per example:  32.8617965392038
# Distance error per example:  157.67244415938984
# Distance error per example:  327.87414394534426
# Distance error per example:  178.22857337515563
# Distance error per example:  42.29554218436894
# Distance error per example:  37.962736080988705
# Distance error per example:  22.572524194925663
# Distance error per example:  98.12098752507586
# Distance error per example:  41.078596898637464
# Distance error per example:  273.41188364063777
# Distance error per example:  59.889219625592034
# Distance error per example:  156.06334943313038
# Distance error per example:  67.00829461214772
# Distance error per example:  90.94795559563269
# Distance error per example:  169.91482702446865
# Distance error per example:  87.44424924550722
# Distance error per example:  82.62749631091323
# Distance error per example:  22.05643710545692
# Distance error per example:  188.87014529763795
# Distance error per example:  131.7815185824692
# Distance error per example:  33.061677158543894
# Distance error per example:  98.59235659023919
# Distance error per example:  33.061677158543894
# Distance error per example:  171.06471851148737
# Distance error per example:  37.50015109077795
# Distance error per example:  33.061677158543894
# Distance error per example:  62.98326807088395
# Distance error per example:  199.86920771359414
# Distance error per example:  279.43075250701816
# Distance error per example:  62.98326807088395
# Distance error per example:  33.061677158543894
# Distance error per example:  33.061677158543894
# Distance error per example:  183.8732068939072
# Distance error per example:  378.0017898430303
# Distance error per example:  259.3620793675587
# Distance error per example:  123.21488037787299
# Distance error per example:  66.90299789087156
# Distance error per example:  146.65698717346578
# Distance error per example:  178.46814758843766
# Distance error per example:  32.01392510677986
# Distance error per example:  79.68066059596904
# Distance error per example:  105.12065061088796
# Distance error per example:  295.36725782622955
# Distance error per example:  45.35515755423418
# Distance error per example:  45.931585288873336
# Distance error per example:  158.9094281142221
# Distance error per example:  131.70442603048687
# Distance error per example:  41.078596898637464
# Distance error per example:  280.16069057676106
# Distance error per example:  26.867820386032488
# Distance error per example:  259.3620793675587
# Distance error per example:  72.36747607853604
# Distance error per example:  192.3908185244865
# Distance error per example:  398.395717122715
# Distance error per example:  32.8617965392038
# Distance error per example:  327.87414394534426
# Distance error per example:  309.19223715254884
# Distance error per example:  509.4791318528689
# Distance error per example:  32.8617965392038
# Distance error per example:  114.25711417684506
# Distance error per example:  121.04572581752565
# Distance error per example:  33.061677158543894
# Distance error per example:  157.69582476596526
# Distance error per example:  46.84750561035332
# Distance error per example:  116.87983427653202
# Distance error per example:  92.24979766366252
# Distance error per example:  49.38523532425377
# Distance error per example:  33.061677158543894
# Distance error per example:  33.061677158543894
# Distance error per example:  116.59808246907743
# Distance error per example:  145.0467924507138
# Distance error per example:  530.6371390527935
# Distance error per example:  23.357798611892317
# Distance error per example:  33.061677158543894
# Distance error per example:  378.0017898430303
# Distance error per example:  23.663317049552543
# Distance error per example:  509.4791318528689
# Distance error per example:  307.83181909939435
# Distance error per example:  105.49382855857702
# Distance error per example:  57.403960315035334
# Distance error per example:  105.49382855857702
# Distance error per example:  254.11927884956393
# Distance error per example:  44.46044525900244
# Distance error per example:  57.403960315035334
# Distance error per example:  137.66406685294362
# Distance error per example:  171.58232659520903
# Distance error per example:  157.86100022159513
# Distance error per example:  27.63704150575152
# Distance error per example:  57.403960315035334
# Distance error per example:  23.149958274053233
# Distance error per example:  131.1453984116416
# Distance error per example:  185.36821042736725
# Distance error per example:  119.65651307884397
# Distance error per example:  169.7587840594868
# Distance error per example:  80.35680218866335
# Distance error per example:  254.11927884956393
# Distance error per example:  21.091774062173833
# Distance error per example:  198.41623170487668
# Distance error per example:  307.83181909939435
# Distance error per example:  52.17952461563766
# Distance error per example:  29.585884774911154
# Distance error per example:  199.86920771359414
# Distance error per example:  29.585884774911154
# Distance error per example:  220.99511684497404
# Distance error per example:  200.63588879260973
# Distance error per example:  107.66312523491774
# Distance error per example:  213.59222723759206
# Distance error per example:  94.3312076951919
# Distance error per example:  34.388298309202305
# Distance error per example:  63.06048069989546
# Distance error per example:  259.3620793675587
# Distance error per example:  57.403960315035334
# Distance error per example:  23.72137529940561
# Distance error per example:  33.061677158543894
# Distance error per example:  183.65605255184897
# Distance error per example:  337.5544693153913
# Distance error per example:  171.06471851148737
# Distance error per example:  51.75739065832323
# Distance error per example:  194.58107245520694
# Distance error per example:  307.83181909939435
# Distance error per example:  33.061677158543894
# Distance error per example:  32.01392510677986
# Distance error per example:  83.24542791326279
# Distance error per example:  17.481974638222354
# Distance error per example:  33.061677158543894
# Distance error per example:  33.061677158543894
# Distance error per example:  33.061677158543894
# Distance error per example:  116.87983427653202
# Distance error per example:  62.49691838498
# Distance error per example:  43.821888283406274
# Distance error per example:  92.7114683987401
# Distance error per example:  90.94795559563269
# Distance error per example:  56.273619417335524
# Distance error per example:  80.86389867584903
# Distance error per example:  327.87414394534426
# Distance error per example:  42.29554218436894
# Distance error per example:  33.84418282546496
# Distance error per example:  191.10448042713708
# Distance error per example:  119.65651307884397
# Distance error per example:  83.7275817577659
# Distance error per example:  174.56914410608152
# Distance error per example:  169.32412575450562
# Distance error per example:  191.10448042713708
# Distance error per example:  169.32412575450562
# Distance error per example:  329.51490117686996
# Distance error per example:  29.585884774911154
# Distance error per example:  138.33125870701363
# Distance error per example:  138.33125870701363
# Distance error per example:  175.4962348849433
# Distance error per example:  77.60475227882019
# Distance error per example:  29.585884774911154
# Distance error per example:  284.4149369177825
# Distance error per example:  22.05643710545692
# Distance error per example:  28.276522767854008
# Distance error per example:  500.5942046496184
# Distance error per example:  214.97168922886434
# Distance error per example:  509.4791318528689
# Distance error per example:  32.01392510677986
# Distance error per example:  128.6197244049999
# Distance error per example:  280.16069057676106
# Distance error per example:  85.61533769158224
# Distance error per example:  22.05643710545692
# Distance error per example:  157.69582476596526
# Distance error per example:  121.33345674256006
# Distance error per example:  33.061677158543894
# Distance error per example:  54.931240207025766
# Distance error per example:  105.49382855857702
# Distance error per example:  80.31019598557502
# Distance error per example:  197.95060244907745
# Distance error per example:  121.33345674256006
# Distance error per example:  109.29295210350719
# Distance error per example:  410.5115617062675
# Distance error per example:  171.06471851148737
# Distance error per example:  95.21516424641585
# Distance error per example:  49.38523532425377
# Distance error per example:  27.95412179032152
# Distance error per example:  49.77695129696436
# Distance error per example:  23.72137529940561
# Distance error per example:  125.73153752370102
# Distance error per example:  105.12065061088796
# Distance error per example:  121.04572581752565
# Distance error per example:  80.86389867584903
# Distance error per example:  34.388298309202305
# Distance error per example:  34.388298309202305
# Distance error per example:  500.5942046496184
# Distance error per example:  32.8617965392038
# Distance error per example:  85.60476948805004
# Distance error per example:  183.48480195554643
# Distance error per example:  105.49382855857702
# Distance error per example:  303.02235418687957
# Distance error per example:  95.02683927999942
# Distance error per example:  49.77695129696436
# Distance error per example:  62.49691838498
# Distance error per example:  162.30910001814553
# Distance error per example:  107.66312523491774
# Distance error per example:  309.66490921249215
# Distance error per example:  77.46618943249985
# Distance error per example:  279.43075250701816
# Distance error per example:  113.89491514149832
# Distance error per example:  238.40935760814855
# Distance error per example:  178.22857337515563
# Distance error per example:  191.86595543490148
# Distance error per example:  83.24542791326279
# Distance error per example:  421.4907997470414
# Distance error per example:  93.54387479181077
# Distance error per example:  277.3611607933173
# Distance error per example:  282.31387059515646
# Distance error per example:  193.6058982832319
# Distance error per example:  22.05643710545692
# Distance error per example:  120.56343577155987
# Distance error per example:  94.00431921815232
# Distance error per example:  21.091774062173833
# Distance error per example:  21.091774062173833
# Distance error per example:  178.22857337515563
# Distance error per example:  156.34134432787593
# Distance error per example:  509.4791318528689
# Distance error per example:  120.2802321751301
# Distance error per example:  116.02520778621391
# Distance error per example:  171.06471851148737
# Distance error per example:  32.8617965392038
# Distance error per example:  55.65477817096692
# Distance error per example:  259.3620793675587
# Distance error per example:  280.16069057676106
# Distance error per example:  93.54387479181077
# Distance error per example:  32.01392510677986
# Distance error per example:  141.62202068864818
# Distance error per example:  131.70442603048687
# Distance error per example:  90.94795559563269
# Distance error per example:  71.35800807830522
# Distance error per example:  22.05643710545692
# Distance error per example:  259.3620793675587
# Distance error per example:  90.94795559563269
# Distance error per example:  60.265603369692585
# Distance error per example:  23.663317049552543
# Distance error per example:  32.01392510677986
# Distance error per example:  143.614093897953
# ...
# Distance error per example:  123.21488037787299
# Distance error per example:  123.21488037787299
# Distance error per example:  37.65587420214649
# Distance error per example:  123.21488037787299
# Distance error per example:  95.21516424641585
# Distance error per example:  49.77695129696436
# Distance error per example:  182.66200036921384
# Distance error per example:  70.17539982736145
# Distance error per example:  121.33345674256006
# Distance error per example:  44.46044525900244
# Distance error per example:  117.71427196136594
# Distance error per example:  259.3620793675587
# Distance error per example:  22.05643710545692
# Distance error per example:  126.23579373857224
# Distance error per example:  34.388298309202305
# Distance error per example:  259.3620793675587
# Distance error per example:  254.11927884956393
# Distance error per example:  122.5819772910399
# Distance error per example:  349.0199983363772
# Distance error per example:  121.33345674256006
# Distance error per example:  49.77695129696436
# Distance error per example:  92.7114683987401
# Distance error per example:  170.68577048788686
# Distance error per example:  174.56914410608152
# Distance error per example:  21.091774062173833
# Distance error per example:  215.17107031067744
# Distance error per example:  51.75739065832323
# Distance error per example:  22.05643710545692
# Distance error per example:  7.03835339535748
# Distance error per example:  58.51212375959558
# Distance error per example:  23.72137529940561
# Distance error per example:  125.73153752370102
# Distance error per example:  386.8506037169624
# Distance error per example:  54.931240207025766
# Distance error per example:  95.21516424641585
# Distance error per example:  71.35800807830522
# Distance error per example:  123.21488037787299
# Distance error per example:  32.01392510677986
# Distance error per example:  117.71427196136594
# Distance error per example:  33.061677158543894
# Distance error per example:  165.2590054386482
# Distance error per example:  57.403960315035334
# Distance error per example:  309.19223715254884
# Distance error per example:  77.60475227882019
# Distance error per example:  127.02268518331452
# Distance error per example:  67.00829461214772
# Distance error per example:  67.00829461214772
# Distance error per example:  326.2029078242937
# Distance error per example:  107.93562734471458
# Distance error per example:  95.78557865606028
# Distance error per example:  34.388298309202305
# Distance error per example:  177.61420727973731
# Distance error per example:  215.17107031067744
# Distance error per example:  122.5819772910399
# Distance error per example:  32.01392510677986
# Distance error per example:  114.25711417684506
# Distance error per example:  34.388298309202305
# Distance error per example:  28.276522767854008
# Distance error per example:  95.78557865606028
# Distance error per example:  92.7114683987401
# Distance error per example:  92.7114683987401
# Distance error per example:  143.14055411971233
# Distance error per example:  157.69582476596526
# Distance error per example:  57.005654606502844
# Distance error per example:  309.19223715254884
# Distance error per example:  22.05643710545692
# Distance error per example:  123.21488037787299
# Distance error per example:  75.14002315356447
# Distance error per example:  41.078596898637464
# Distance error per example:  23.72137529940561
# Distance error per example:  22.05643710545692
# Distance error per example:  58.51212375959558
# Distance error per example:  254.11927884956393
# Distance error per example:  94.3312076951919
# Distance error per example:  58.51212375959558
# Distance error per example:  92.7114683987401
# Distance error per example:  384.3182877969654
# Distance error per example:  57.403960315035334
# Distance error per example:  58.51212375959558
# Distance error per example:  125.50685694218681
# Distance error per example:  37.65587420214649
# Distance error per example:  155.5341400796622
# Distance error per example:  88.45011428531748
# Distance error per example:  72.41042087711992
# Distance error per example:  123.21488037787299
# Distance error per example:  34.388298309202305
# Distance error per example:  116.87983427653202
# Distance error per example:  167.74392953979697
# Distance error per example:  120.35276132847913
# Distance error per example:  146.561400117331
# Distance error per example:  94.3312076951919
# Distance error per example:  49.77695129696436
# Distance error per example:  37.65587420214649
# Distance error per example:  37.65587420214649
# Distance error per example:  37.65587420214649
# Distance error per example:  23.72137529940561
# Distance error per example:  157.0801298435918
# Distance error per example:  72.41042087711992
# Distance error per example:  76.730406666671
# Distance error per example:  282.6661205546286
# Distance error per example:  58.51212375959558
# Distance error per example:  75.14002315356447
# Distance error per example:  67.00829461214772
# Distance error per example:  57.403960315035334
# Distance error per example:  32.01392510677986
# Distance error per example:  131.28045343028674
# Distance error per example:  27.95412179032152
# Distance error per example:  49.77695129696436
# Distance error per example:  56.26066694616735
# Distance error per example:  37.65587420214649
# Distance error per example:  254.11927884956393
# Distance error per example:  85.13145080046566
# Distance error per example:  49.77695129696436
# Distance error per example:  309.19223715254884
# Distance error per example:  232.59173245051144
# Distance error per example:  22.05643710545692
# Distance error per example:  41.078596898637464
# Distance error per example:  259.3620793675587
# Distance error per example:  28.276522767854008
# Distance error per example:  95.78557865606028
# Distance error per example:  309.19223715254884
# Distance error per example:  105.49382855857702
# Distance error per example:  108.85673251383064
# Distance error per example:  193.6058982832319
# Distance error per example:  23.357798611892317
# Distance error per example:  58.51212375959558
# Distance error per example:  37.65587420214649
# Distance error per example:  45.35515755423418
# Distance error per example:  23.72137529940561
# Distance error per example:  100.44410152713839
# Distance error per example:  22.05643710545692
# Distance error per example:  16.370799498034835
# Distance error per example:  16.370799498034835
# Distance error per example:  155.5341400796622
# Distance error per example:  123.21488037787299
# Distance error per example:  105.14204140411249
# Distance error per example:  58.51212375959558
# Distance error per example:  456.8694964061595
# Distance error per example:  105.49382855857702
# Distance error per example:  124.22922945137817
# Distance error per example:  193.6058982832319
# Distance error per example:  37.962736080988705
# Distance error per example:  37.962736080988705
# Distance error per example:  75.14002315356447
# Distance error per example:  32.01392510677986
# Distance error per example:  32.01392510677986
# Distance error per example:  32.01392510677986
# Distance error per example:  75.14002315356447
# Distance error per example:  174.56914410608152
# Distance error per example:  37.962736080988705
# Distance error per example:  174.56914410608152
# Distance error per example:  114.25711417684506
# Distance error per example:  62.98326807088395
# Distance error per example:  123.21488037787299
# Distance error per example:  174.56914410608152
# Distance error per example:  169.7587840594868
# Distance error per example:  171.5624467941342
# Distance error per example:  23.72137529940561
# Distance error per example:  49.77695129696436
# Distance error per example:  156.06334943313038
# Distance error per example:  156.06334943313038
# Distance error per example:  22.05643710545692
# Distance error per example:  178.22857337515563
# Distance error per example:  307.83181909939435
# Distance error per example:  51.75739065832323
# Distance error per example:  193.6058982832319
# Distance error per example:  67.00829461214772
# Distance error per example:  192.3908185244865
# Distance error per example:  259.3620793675587
# Distance error per example:  131.1453984116416
# Distance error per example:  123.21488037787299
# Distance error per example:  123.21488037787299
# Distance error per example:  326.2029078242937
# Distance error per example:  23.72137529940561
# Distance error per example:  23.72137529940561
# Distance error per example:  45.35515755423418
# Distance error per example:  71.35800807830522
# Distance error per example:  49.38523532425377
# Distance error per example:  23.663317049552543
# Distance error per example:  57.403960315035334
# Distance error per example:  127.02268518331452
# Distance error per example:  23.72137529940561
# Distance error per example:  77.60475227882019
# Distance error per example:  358.33506012865064
# Distance error per example:  7.03835339535748
# Distance error per example:  178.22857337515563
# Distance error per example:  80.86389867584903
# Distance error per example:  378.0017898430303
# Distance error per example:  37.962736080988705
# Distance error per example:  49.77695129696436
# Distance error per example:  259.3620793675587
# Distance error per example:  146.561400117331
# Distance error per example:  364.66771694715334
# Distance error per example:  254.11927884956393
# Distance error per example:  185.36821042736725
# Distance error per example:  16.370799498034835
# Distance error per example:  80.35680218866335
# Distance error per example:  23.72137529940561
# Distance error per example:  113.89491514149832
# Distance error per example:  37.65587420214649
# Distance error per example:  23.72137529940561
# Distance error per example:  146.561400117331
# Distance error per example:  34.388298309202305
# Distance error per example:  177.19857816357236
# Distance error per example:  71.57838600620315
# Distance error per example:  56.26066694616735
# Distance error per example:  26.867820386032488
# Distance error per example:  34.388298309202305
# Distance error per example:  23.72137529940561
# Distance error per example:  49.38523532425377
# Distance error per example:  254.11927884956393
# Distance error per example:  207.15488477391213
# Distance error per example:  75.14002315356447
# Distance error per example:  92.7114683987401
# Distance error per example:  94.3312076951919
# Distance error per example:  77.60475227882019
# Distance error per example:  22.05643710545692
# Distance error per example:  113.89491514149832
# Distance error per example:  64.75544497993789
# Distance error per example:  58.51212375959558
# Distance error per example:  62.98326807088395
# Distance error per example:  174.56914410608152
# Distance error per example:  95.22929061762252
# Distance error per example:  62.49691838498
# Distance error per example:  193.6058982832319
# Distance error per example:  193.6058982832319
# Distance error per example:  105.49382855857702
# Distance error per example:  158.4676212458365
# Distance error per example:  251.33319939094588
# Distance error per example:  45.35515755423418
# Distance error per example:  176.1996101110795
# Distance error per example:  117.71427196136594
# Distance error per example:  95.22929061762252
# Distance error per example:  58.51212375959558
# Distance error per example:  76.730406666671
# Distance error per example:  62.98326807088395
# Distance error per example:  18.99571009855775
# Distance error per example:  23.357798611892317
# Distance error per example:  95.21516424641585
# Distance error per example:  23.72137529940561
# Distance error per example:  253.27921127632067
# Distance error per example:  27.95412179032152
# Distance error per example:  436.26987741146684
# Distance error per example:  436.5966258889825
# Distance error per example:  254.11927884956393
# Distance error per example:  67.00829461214772
# Distance error per example:  67.00829461214772
# Distance error per example:  55.65477817096692
# Distance error per example:  108.85673251383064
# Distance error per example:  75.14002315356447
# Distance error per example:  95.22929061762252
# Distance error per example:  121.33345674256006
# Distance error per example:  95.78557865606028
# Distance error per example:  105.49382855857702
# Distance error per example:  23.72137529940561
# Distance error per example:  197.8060402364497
# Distance error per example:  193.6058982832319
# Distance error per example:  123.21488037787299
# Distance error per example:  280.16069057676106
# Distance error per example:  95.22929061762252
# Distance error per example:  95.21516424641585
# Distance error per example:  75.14002315356447
# Distance error per example:  364.66771694715334
# Distance error per example:  156.06334943313038
# Distance error per example:  254.11927884956393
# Distance error per example:  67.00829461214772
# Distance error per example:  58.51212375959558
# Distance error per example:  67.00829461214772
# Distance error per example:  95.22929061762252
# Distance error per example:  80.31019598557502
# Distance error per example:  49.38523532425377
# Distance error per example:  254.11927884956393
# Distance error per example:  95.21516424641585
# Distance error per example:  331.7619444572871
# Distance error per example:  95.78557865606028
# Distance error per example:  94.3312076951919
# Distance error per example:  105.49382855857702
# Distance error per example:  170.68577048788686
# Distance error per example:  78.186478277133
# Distance error per example:  174.56914410608152
# Distance error per example:  56.273619417335524
# Distance error per example:  110.00721568166408
# Distance error per example:  158.4676212458365
# Distance error per example:  280.16069057676106
# Distance error per example:  67.00829461214772
# Distance error per example:  155.5341400796622
# Distance error per example:  45.35515755423418
# Distance error per example:  7.03835339535748
# Distance error per example:  259.3620793675587
# Distance error per example:  67.00829461214772
# Distance error per example:  94.3312076951919
# Distance error per example:  95.78557865606028
# Distance error per example:  155.5341400796622
# Distance error per example:  18.99571009855775
# Distance error per example:  91.44793352575839
# Distance error per example:  91.44793352575839
# Distance error per example:  282.3469099669154
# Distance error per example:  108.85673251383064
# Distance error per example:  62.98326807088395
# Distance error per example:  192.9436323567007
# Distance error per example:  77.23996119875174
# Distance error per example:  535.3205673924982
# Distance error per example:  23.72137529940561
# Distance error per example:  113.89739688363908
# Distance error per example:  75.14002315356447
# Distance error per example:  174.56914410608152
# Distance error per example:  119.65651307884397
# Distance error per example:  309.19223715254884
# Distance error per example:  253.27921127632067
# Distance error per example:  18.99571009855775
# Distance error per example:  90.56160779239458
# Distance error per example:  94.3312076951919
# Distance error per example:  193.6058982832319
# Distance error per example:  92.7114683987401
# Distance error per example:  97.19484073812664
# Distance error per example:  62.98326807088395
# Distance error per example:  32.01392510677986
# Distance error per example:  33.061677158543894
# Distance error per example:  94.3312076951919
# Distance error per example:  123.21488037787299
# Distance error per example:  193.6058982832319
# Distance error per example:  183.48480195554643
# Distance error per example:  95.78557865606028
# Distance error per example:  200.39849918346744
# Distance error per example:  526.3945772906269
# Distance error per example:  309.19223715254884
# Distance error per example:  94.3312076951919
# Distance error per example:  535.3205673924982
# Distance error per example:  23.72137529940561
# Distance error per example:  88.22675796600377
# Distance error per example:  32.01392510677986
# Distance error per example:  95.21516424641585
# Distance error per example:  33.061677158543894
# Distance error per example:  121.33345674256006
# Distance error per example:  272.82126922637553
# Distance error per example:  203.73062609685283
# Distance error:  495888.0583150076
# average distance error:  108.22524188454989
